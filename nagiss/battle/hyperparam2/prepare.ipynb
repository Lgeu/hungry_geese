# %%
# mean
# !g++ ../../../KKT89/_Combine.cpp -O3 -Ofast -march=native -std=c++17 -o mean
# Out:
# In file included from ../../../KKT89/src/Goose.hpp:3,
#                  from ../../../KKT89/src/Stage.hpp:4,
#                  from ../../../KKT89/src/Duct.hpp:7,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/_Combine.cpp:3:
# ../../../KKT89/src/Evaluator2.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::ShiftRight()’:
# ../../../KKT89/src/library.hpp:64:9: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘hungry_geese::evaluation_function::BitBoard::ull’ {aka ‘long long unsigned int’} [-Wformat=]
#    64 |         "`%s` (%d) is out of range [%d, %d)", #value, value, left, right)
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ../../../KKT89/src/library.hpp:54:24: note: in definition of macro ‘ASSERT’
#    54 |                 printf(__VA_ARGS__); \
#       |                        ^~~~~~~~~~~
# ...

# %%
# alphazero
# !g++ ../../../KKT89/_Combine.cpp -O3 -Ofast -march=native -std=c++17 -o alphazero
# Out:
# In file included from ../../../KKT89/src/Goose.hpp:3,
#                  from ../../../KKT89/src/Stage.hpp:4,
#                  from ../../../KKT89/src/Duct.hpp:7,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/_Combine.cpp:3:
# ../../../KKT89/src/Evaluator2.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::ShiftRight()’:
# ../../../KKT89/src/library.hpp:64:9: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘hungry_geese::evaluation_function::BitBoard::ull’ {aka ‘long long unsigned int’} [-Wformat=]
#    64 |         "`%s` (%d) is out of range [%d, %d)", #value, value, left, right)
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ../../../KKT89/src/library.hpp:54:24: note: in definition of macro ‘ASSERT’
#    54 |                 printf(__VA_ARGS__); \
#       |                        ^~~~~~~~~~~
# ...

# %%
# alphazero c_puct=4
# !g++ ../../../KKT89/_Combine.cpp -O3 -Ofast -march=native -std=c++17 -o alphazero_c4
# Out:
# In file included from ../../../KKT89/src/Goose.hpp:3,
#                  from ../../../KKT89/src/Stage.hpp:4,
#                  from ../../../KKT89/src/Duct.hpp:7,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/_Combine.cpp:3:
# ../../../KKT89/src/Evaluator2.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::ShiftRight()’:
# ../../../KKT89/src/library.hpp:64:9: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘hungry_geese::evaluation_function::BitBoard::ull’ {aka ‘long long unsigned int’} [-Wformat=]
#    64 |         "`%s` (%d) is out of range [%d, %d)", #value, value, left, right)
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ../../../KKT89/src/library.hpp:54:24: note: in definition of macro ‘ASSERT’
#    54 |                 printf(__VA_ARGS__); \
#       |                        ^~~~~~~~~~~
# ...

# %%
# alphazero c_puct=0.25
# !g++ ../../../KKT89/_Combine.cpp -O3 -Ofast -march=native -std=c++17 -o alphazero_c0.25
# Out:
# In file included from ../../../KKT89/src/Goose.hpp:3,
#                  from ../../../KKT89/src/Stage.hpp:4,
#                  from ../../../KKT89/src/Duct.hpp:7,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/_Combine.cpp:3:
# ../../../KKT89/src/Evaluator2.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::ShiftRight()’:
# ../../../KKT89/src/library.hpp:64:9: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘hungry_geese::evaluation_function::BitBoard::ull’ {aka ‘long long unsigned int’} [-Wformat=]
#    64 |         "`%s` (%d) is out of range [%d, %d)", #value, value, left, right)
#       |         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ../../../KKT89/src/library.hpp:54:24: note: in definition of macro ‘ASSERT’
#    54 |                 printf(__VA_ARGS__); \
#       |                        ^~~~~~~~~~~
# ...

# %%
# !diff mean alphazero
# !diff mean alphazero_c4
# !diff mean alphazero_c0.25
# !diff alphazero alphazero_c4
# !diff alphazero alphazero_c0.25
# !diff alphazero_c4 alphazero_c0.25
# Out:
# Binary files mean and alphazero differ
# Binary files mean and alphazero_c4 differ
# Binary files mean and alphazero_c0.25 differ
# Binary files alphazero and alphazero_c4 differ
# Binary files alphazero and alphazero_c0.25 differ
# Binary files alphazero_c4 and alphazero_c0.25 differ

# %%
# !mkdir bak
# !cp mean bak
# !cp alphazero bak
# !cp alphazero_c4 bak
# !cp alphazero_c0.25 bak
# Out:
# mkdir: cannot create directory ‘bak’: File exists

# %%
# %%writefile mean.py

import sys
from subprocess import Popen, PIPE, STDOUT
from kaggle_environments.envs.hungry_geese.hungry_geese import Action

parameter_file = "../../rl/parameters/038_01.bin"
cmd = ["./mean", "-p", parameter_file, "-t", "0.1"]
p = Popen(cmd, stdin=PIPE, stdout=PIPE, stderr=STDOUT)


def print_environment():
    p = Popen(r"""g++ -### -E - -march=native 2>&1 | sed -r '/cc1/!d;s/(")|(^.* - )|( -mno-[^\ ]+)//g'""", stdout=PIPE, shell=True)
    print(p.stdout.readline().decode().strip())

def write_obs(obs):
    # example:
    # 60.0         # time
    # 6            # step
    # 1 5          # goose (player)
    # 1 0          # goose (opponent)
    # 0            # goose (opponent)
    # 3 7 8 9      # goose (opponent)
    # 40 47        # foods
    
    def write(*args):
        p.stdin.write(f"{' '.join(map(str, args))}\n".encode())
    write(obs["remainingOverageTime"])
    write(obs["step"])
    for goose in obs["geese"]:
        write(len(goose), *goose)
    write(*obs["food"])
    
    p.stdin.flush()

def agent(obs_dict, config_dict):
    if obs_dict["index"] != 0:
        # swap geese
        obs_dict["geese"][0], obs_dict["geese"][obs_dict["index"]] = obs_dict["geese"][obs_dict["index"]], obs_dict["geese"][0]
    write_obs(obs_dict)
    
    #if obs_dict["step"] == 0:
    #    print_environment()

    while True:
        input_values = p.stdout.readline().decode().strip().split()
        if len(input_values) == 0:
            continue
        if input_values[0] == "move":
            direction = input_values[1]
            if direction == "l":
                return Action.WEST.name
            elif direction == "r":
                return Action.EAST.name
            elif direction == "u":
                return Action.NORTH.name
            elif direction == "d":
                return Action.SOUTH.name
            else:
                assert False, f"invalid move {direction}"
        else:
            print(*input_values)
# Out:
# Overwriting mean.py

# %%
# %%writefile alphazero.py

import sys
from subprocess import Popen, PIPE, STDOUT
from kaggle_environments.envs.hungry_geese.hungry_geese import Action

parameter_file = "../../rl/parameters/038_01.bin"
cmd = ["./alphazero", "-p", parameter_file, "-t", "0.1"]
p = Popen(cmd, stdin=PIPE, stdout=PIPE, stderr=STDOUT)


def print_environment():
    p = Popen(r"""g++ -### -E - -march=native 2>&1 | sed -r '/cc1/!d;s/(")|(^.* - )|( -mno-[^\ ]+)//g'""", stdout=PIPE, shell=True)
    print(p.stdout.readline().decode().strip())

def write_obs(obs):
    # example:
    # 60.0         # time
    # 6            # step
    # 1 5          # goose (player)
    # 1 0          # goose (opponent)
    # 0            # goose (opponent)
    # 3 7 8 9      # goose (opponent)
    # 40 47        # foods
    
    def write(*args):
        p.stdin.write(f"{' '.join(map(str, args))}\n".encode())
    write(obs["remainingOverageTime"])
    write(obs["step"])
    for goose in obs["geese"]:
        write(len(goose), *goose)
    write(*obs["food"])
    
    p.stdin.flush()

def agent(obs_dict, config_dict):
    if obs_dict["index"] != 0:
        # swap geese
        obs_dict["geese"][0], obs_dict["geese"][obs_dict["index"]] = obs_dict["geese"][obs_dict["index"]], obs_dict["geese"][0]
    write_obs(obs_dict)
    
    #if obs_dict["step"] == 0:
    #    print_environment()

    while True:
        input_values = p.stdout.readline().decode().strip().split()
        if len(input_values) == 0:
            continue
        if input_values[0] == "move":
            direction = input_values[1]
            if direction == "l":
                return Action.WEST.name
            elif direction == "r":
                return Action.EAST.name
            elif direction == "u":
                return Action.NORTH.name
            elif direction == "d":
                return Action.SOUTH.name
            else:
                assert False, f"invalid move {direction}"
        else:
            print(*input_values)
# Out:
# Overwriting alphazero.py

# %%
# %%writefile alphazero_c4.py

import sys
from subprocess import Popen, PIPE, STDOUT
from kaggle_environments.envs.hungry_geese.hungry_geese import Action

parameter_file = "../../rl/parameters/038_01.bin"
cmd = ["./alphazero_c4", "-p", parameter_file, "-t", "0.1"]
p = Popen(cmd, stdin=PIPE, stdout=PIPE, stderr=STDOUT)


def print_environment():
    p = Popen(r"""g++ -### -E - -march=native 2>&1 | sed -r '/cc1/!d;s/(")|(^.* - )|( -mno-[^\ ]+)//g'""", stdout=PIPE, shell=True)
    print(p.stdout.readline().decode().strip())

def write_obs(obs):
    # example:
    # 60.0         # time
    # 6            # step
    # 1 5          # goose (player)
    # 1 0          # goose (opponent)
    # 0            # goose (opponent)
    # 3 7 8 9      # goose (opponent)
    # 40 47        # foods
    
    def write(*args):
        p.stdin.write(f"{' '.join(map(str, args))}\n".encode())
    write(obs["remainingOverageTime"])
    write(obs["step"])
    for goose in obs["geese"]:
        write(len(goose), *goose)
    write(*obs["food"])
    
    p.stdin.flush()

def agent(obs_dict, config_dict):
    if obs_dict["index"] != 0:
        # swap geese
        obs_dict["geese"][0], obs_dict["geese"][obs_dict["index"]] = obs_dict["geese"][obs_dict["index"]], obs_dict["geese"][0]
    write_obs(obs_dict)
    
    #if obs_dict["step"] == 0:
    #    print_environment()

    while True:
        input_values = p.stdout.readline().decode().strip().split()
        if len(input_values) == 0:
            continue
        if input_values[0] == "move":
            direction = input_values[1]
            if direction == "l":
                return Action.WEST.name
            elif direction == "r":
                return Action.EAST.name
            elif direction == "u":
                return Action.NORTH.name
            elif direction == "d":
                return Action.SOUTH.name
            else:
                assert False, f"invalid move {direction}"
        else:
            print(*input_values)
# Out:
# Writing alphazero_c4.py

# %%
# %%writefile alphazero_c0.25.py

import sys
from subprocess import Popen, PIPE, STDOUT
from kaggle_environments.envs.hungry_geese.hungry_geese import Action

parameter_file = "../../rl/parameters/038_01.bin"
cmd = ["./alphazero_c0.25", "-p", parameter_file, "-t", "0.1"]
p = Popen(cmd, stdin=PIPE, stdout=PIPE, stderr=STDOUT)


def print_environment():
    p = Popen(r"""g++ -### -E - -march=native 2>&1 | sed -r '/cc1/!d;s/(")|(^.* - )|( -mno-[^\ ]+)//g'""", stdout=PIPE, shell=True)
    print(p.stdout.readline().decode().strip())

def write_obs(obs):
    # example:
    # 60.0         # time
    # 6            # step
    # 1 5          # goose (player)
    # 1 0          # goose (opponent)
    # 0            # goose (opponent)
    # 3 7 8 9      # goose (opponent)
    # 40 47        # foods
    
    def write(*args):
        p.stdin.write(f"{' '.join(map(str, args))}\n".encode())
    write(obs["remainingOverageTime"])
    write(obs["step"])
    for goose in obs["geese"]:
        write(len(goose), *goose)
    write(*obs["food"])
    
    p.stdin.flush()

def agent(obs_dict, config_dict):
    if obs_dict["index"] != 0:
        # swap geese
        obs_dict["geese"][0], obs_dict["geese"][obs_dict["index"]] = obs_dict["geese"][obs_dict["index"]], obs_dict["geese"][0]
    write_obs(obs_dict)
    
    #if obs_dict["step"] == 0:
    #    print_environment()

    while True:
        input_values = p.stdout.readline().decode().strip().split()
        if len(input_values) == 0:
            continue
        if input_values[0] == "move":
            direction = input_values[1]
            if direction == "l":
                return Action.WEST.name
            elif direction == "r":
                return Action.EAST.name
            elif direction == "u":
                return Action.NORTH.name
            elif direction == "d":
                return Action.SOUTH.name
            else:
                assert False, f"invalid move {direction}"
        else:
            print(*input_values)
# Out:
# Writing alphazero_c0.25.py

# %%
# %%writefile battle.py
from kaggle_environments import make

env = make("hungry_geese", debug=False)
def env_to_rank(env):
    rewards = [goose["reward"] for goose in env.state]
    return rewards
env.reset()
env.run(["mean.py", "alphazero.py", "alphazero_c4.py", "alphazero_c0.25.py"])   ###
res = env_to_rank(env)
print(f"{res},")
# Out:
# Overwriting battle.py

# %%
from kaggle_environments import make

env = make("hungry_geese", debug=True)
result = []
def env_to_rank(env):
    rewards = [goose["reward"] for goose in env.state]
    return rewards
for i in range(2):
    env.reset()
    env.run(["mean.py", "alphazero.py", "alphazero_c4.py", "alphazero_c0.25.py"])   ###
    res = env_to_rank(env)
    result.append(res)
    print(f"{res},")
    env.render(mode="ipython", width=700, height=600)
# Out:
# Loading environment football failed: No module named 'gfootball'
# [20007, 20006, 20015, 20017],
# <iframe srcdoc="<!--
#   Copyright 2020 Kaggle Inc
#
#   Licensed under the Apache License, Version 2.0 (the &quot;License&quot;);
#   you may not use this file except in compliance with the License.
#   You may obtain a copy of the License at
#
#       http://www.apache.org/licenses/LICENSE-2.0
#
#   Unless required by applicable law or agreed to in writing, software
#   distributed under the License is distributed on an &quot;AS IS&quot; BASIS,
#   WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   See the License for the specific language governing permissions and
#   limitations under the License.
# -->
# <!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <title>Kaggle Simulation Player</title>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot; />
#     <link
#       rel=&quot;stylesheet&quot;
# ...
