# %%
# !g++ Combine.cpp -O3 -Ofast -std=c++17 -march=native -Wall -Wextra
# Out:
# In file included from Combine.cpp:10:
# src/GreedyAgent.cpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Print() const’:
# src/GreedyAgent.cpp:636:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   636 |                 cout << ((lo >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# src/GreedyAgent.cpp:642:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   642 |                 cout << ((hi >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# src/GreedyAgent.cpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Flip(const int&)’:
# src/GreedyAgent.cpp:649:32: warning: suggest parentheses around ‘-’ inside ‘<<’ [-Wparentheses]
#   649 |         else hi ^= 1ull << idx - 55;
#       |                            ~~~~^~~~
# In file included from src/GreedyAgent.cpp:5,
#                  from Combine.cpp:10:
# ...

# %%
# !./a.out
# Out:
# -1.07251 -4.77588 2.80078 2.46143 2.88965
# -0.955078 1.59546 3.35034 2.20654 -5.74927
# -1.61426 -2.6665 1.86377 -1.90381 5.52075
# -2.05542 -3.9126 4.10303 -1.52881 3.37622
