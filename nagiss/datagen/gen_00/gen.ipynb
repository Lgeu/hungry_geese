# %%
ls ../../../KKT89
# Out:
# 7_17/  Combine.cpp  src/

# %%
# !g++ ../../../KKT89/Combine.cpp -O3 -Ofast -std=c++17 -march=native -Wall -Wextra
# Out:
# In file included from ../../../KKT89/Combine.cpp:1:
# ../../../KKT89/src/Duct.cpp: In static member function ‘static void hungry_geese::Duct::State::Simulate(hungry_geese::Duct::State&, unsigned char)’:
# ../../../KKT89/src/Duct.cpp:138:83: warning: implicitly-declared ‘constexpr hungry_geese::Duct::Cpoint::Cpoint(const hungry_geese::Duct::Cpoint&)’ is deprecated [-Wdeprecated-copy]
#   138 | uct::Translate(state.geese[state.boundary[i]], agent_action%4);
#       |                                                              ^
#
# In file included from ../../../KKT89/Combine.cpp:1:
# ../../../KKT89/src/Duct.cpp:40:15: note: because ‘hungry_geese::Duct::Cpoint’ has user-provided ‘hungry_geese::Duct::Cpoint& hungry_geese::Duct::Cpoint::operator=(const hungry_geese::Duct::Cpoint&)’
#    40 | Duct::Cpoint& Duct::Cpoint::operator= (const Cpoint &aPos) {
#       |               ^~~~
# In file included from ../../../KKT89/src/Duct.cpp:2,
# ...

# %%
# !mkdir data

# %%
# !seq 1 10000 | xargs -I@ -P 62 sh -c './a.out -j -o ./data/ -t 0.1 -p legacy legacy legacy legacy'
