# %%
# https://github.com/Lgeu/hungry_geese/commit/88966b3410ef0b481dc144264cf71676fae3b7fc

# !g++ ../../../KKT89/Combine.cpp -O3 -Ofast -march=native -std=c++17 -Wall -Wextra
# Out:
# In file included from ../../../KKT89/src/Duct.hpp:10,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/Combine.cpp:3:
# ../../../KKT89/src/Evaluator.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Print() const’:
# ../../../KKT89/src/Evaluator.hpp:640:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   640 |                 cout << ((lo >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# ../../../KKT89/src/Evaluator.hpp:646:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   646 |                 cout << ((hi >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# ../../../KKT89/src/Evaluator.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Flip(const int&)’:
# ../../../KKT89/src/Evaluator.hpp:653:32: warning: suggest parentheses around ‘-’ inside ‘<<’ [-Wparentheses]
# ...

# %%
out_dir = "./data4/"

# %%
# !mkdir {out_dir}
# Out:
# mkdir: cannot create directory ‘./data4/’: File exists

# %%
param = "../../../KKT89/src/param_010_01.bin"
# !seq 1 100000 | xargs -I@ -P 63 sh -c './a.out -j -o {out_dir} -t 0.1 -p {param} {param} {param} {param}'
# Out:
# ^C
