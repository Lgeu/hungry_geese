# %%
# !g++ ../../../KKT89/Combine.cpp -O3 -Ofast -march=native -std=c++17 -Wall -Wextra
# Out:
# In file included from ../../../KKT89/src/Duct.hpp:10,
#                  from ../../../KKT89/src/Duct.cpp:2,
#                  from ../../../KKT89/Combine.cpp:3:
# ../../../KKT89/src/Evaluator.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Print() const’:
# ../../../KKT89/src/Evaluator.hpp:640:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   640 |                 cout << ((lo >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# ../../../KKT89/src/Evaluator.hpp:646:40: warning: suggest parentheses around ‘+’ inside ‘>>’ [-Wparentheses]
#   646 |                 cout << ((hi >> y * 11 + x) & 1);
#       |                                 ~~~~~~~^~~
# ../../../KKT89/src/Evaluator.hpp: In member function ‘void hungry_geese::evaluation_function::BitBoard::Flip(const int&)’:
# ../../../KKT89/src/Evaluator.hpp:653:32: warning: suggest parentheses around ‘-’ inside ‘<<’ [-Wparentheses]
# ...

# %%
# !mkdir check

# %%
# !./a.out -j -t 0.3 -o check -p ../../../KKT89/src/param_010_01.bin ../../../KKT89/src/param_010_01.bin ../../../KKT89/src/param_010_01.bin ../../../KKT89/src/param_010_01.bin
# Out:
# 0 0 1 81
# 0 0 1 81
# 0 0 1 81
# 0 0 1 81
# 1 45363 45363 3674403
# 1 45423 45423 3679263
# 1 45597 45597 3693357
# 1 45080 45080 3651480
# 2 45932 45932 3720492
# 2 45316 45316 3670596
# 2 46072 46072 3731832
# 2 45102 45102 3653262
# 3 46214 46214 3743334
# 3 45358 45358 3673998
# 3 45645 45645 3697245
# 3 45933 45933 3720573
# 4 46608 50564 4056124
# 4 46689 50532 4054662
# 4 46527 50238 4032168
# 4 46770 50560 4057460
# 5 44534 45907 3703364
# 5 44871 46283 3733391
# 5 45697 47169 3804497
# 5 45212 46620 3760732
# 6 44660 44660 3617460
# 6 44596 44596 3612276
# 6 44751 44751 3624831
# 6 45214 45214 3662334
# 7 43033 43033 3485673
# 7 43668 43668 3537108
# 7 43590 43590 3530790
# 7 43369 43369 3512889
# 8 46222 48847 3925107
# 8 45706 48025 3862197
# 8 46160 48694 3913806
# 8 45695 48109 3867861
# 9 43329 43329 3509649
# 9 43720 43720 3541320
# 9 43073 43073 3488913
# 9 43594 43594 3531114
# 10 45794 49311 3948470
# 10 46609 50233 4021761
# 10 46221 49894 3993665
# ...

# %%
# !mv a.out check.out
